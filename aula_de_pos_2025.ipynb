# %% [markdown]
# <a href="https://colab.research.google.com/github/eniohandy/aula/blob/main/aula_de_pos_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importação de Dados

# %%
# copia do banco de dados do artigo, que cita os dados deste teste
from os.path import exists
if (exists('/content/aula/') == False):
   ! git clone https://github.com/eniohandy/aula.git
# !ls
# !pwd
# Out:
# Cloning into 'aula'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), 7.70 KiB | 606.00 KiB/s, done.
# aula  sample_data
# /content

# %%
# muda para diretorio onde esta o arquivo de teste
# %cd /content/aula/
# !pwd
# Out:
# /content/aula
# /content/aula

# %%
#lista os arquivos
# !ls
# Out:
# GE_RefractoryAlloyScreeningDataset_FINAL.csv  parole.csv  README

# %%
# pacotes basicos para o teste
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv('parole.csv')
dataset
# Out:
#      male  race   age  state  time.served  max.sentence  multiple.offenses  \
# 0       1     1  33.2      1          5.5            18                  0
# 1       0     1  39.7      1          5.4            12                  0
# 2       1     2  29.5      1          5.6            12                  0
# 3       1     1  22.4      1          5.7            18                  0
# 4       1     2  21.6      1          5.4            12                  0
# ..    ...   ...   ...    ...          ...           ...                ...
# 670     1     1  47.1      4          4.2            16                  1
# 671     0     1  47.5      1          5.2            16                  0
# 672     1     1  45.4      1          5.7            12                  0
# 673     1     1  38.4      1          1.8            18                  0
# 674     1     1  47.8      1          6.0            12                  0
#
#      crime  violator
# 0        4         0
# 1        3         0
# ...

# %%
dataset.describe()
# Out:
#              male        race         age       state  time.served  \
# count  675.000000  675.000000  675.000000  675.000000   675.000000
# mean     0.807407    1.423704   34.512296    2.887407     4.198074
# std      0.394628    0.494511   10.351541    1.226224     1.226855
# min      0.000000    1.000000   18.400000    1.000000     0.000000
# 25%      1.000000    1.000000   25.350000    2.000000     3.250000
# 50%      1.000000    1.000000   33.700000    3.000000     4.400000
# 75%      1.000000    2.000000   42.550000    4.000000     5.200000
# max      1.000000    2.000000   67.000000    4.000000     6.000000
#
#        max.sentence  multiple.offenses       crime    violator
# count    675.000000         675.000000  675.000000  675.000000
# mean      13.056296           0.536296    2.059259    0.115556
# std        3.056797           0.499051    1.135892    0.319928
# min        1.000000           0.000000    1.000000    0.000000
# ...

# %%
from matplotlib import pyplot as plt
dataset['crime'].plot(kind='hist', bins=20, title='crime')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
dataset['age'].plot(kind='hist', bins=20, title='age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
sns.scatterplot(data=dataset, x="age", y="crime", hue="violator")
# Out:
# <Axes: xlabel='age', ylabel='crime'>

# %%
from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(dataset[:7], dataset[:8], test_size=0.3)
dataset.iloc[:,8]
dataset.iloc[:,0:7]
# Out:
#      male  race   age  state  time.served  max.sentence  multiple.offenses
# 0       1     1  33.2      1          5.5            18                  0
# 1       0     1  39.7      1          5.4            12                  0
# 2       1     2  29.5      1          5.6            12                  0
# 3       1     1  22.4      1          5.7            18                  0
# 4       1     2  21.6      1          5.4            12                  0
# ..    ...   ...   ...    ...          ...           ...                ...
# 670     1     1  47.1      4          4.2            16                  1
# 671     0     1  47.5      1          5.2            16                  0
# 672     1     1  45.4      1          5.7            12                  0
# 673     1     1  38.4      1          1.8            18                  0
# 674     1     1  47.8      1          6.0            12                  0
#
# [675 rows x 7 columns]

# %% [markdown]
# #PARTE DA HOLISTIC AI - TEST

# %%
# import holistic test
# !pip install -q holisticai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.7/423.7 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 kB 15.5 MB/s eta 0:00:00

# %%
from holisticai.datasets import load_dataset

dataset = load_dataset('law_school')
dataset.data # retorna os dados brutos (com esse objeto acessamos o que é importante para treinar os modelos, métricas e mitigadores)

##
# Veja que o dataset não retorna nada!
##

#dataset_split = dataset.train_test_split(test_size=0.3)

# some stats about the data
# dataset_split(x)
# Out:
# features          X                                              y    p_attrs  \
# subfeatures decile1 decile3 fam_inc  lsat ugpa cluster fulltime  y      race1
# 0                10      10       5  44.0  3.5       1        1  1      white
# 1                 5       4       4  29.0  3.5       2        1  1      white
# 2                 8       7       3  37.0  3.4       1        1  1      white
# 3                 8       7       4  43.0  3.3       1        1  1      white
# 4                 3       2       4  41.0  3.3       4        1  1      white
# ...             ...     ...     ...   ...  ...     ...      ... ..        ...
# 20795             9       8       4  42.0  3.0       5        1  1      white
# 20796             4       9       4  29.5  3.5       3        1  1      white
# 20797             1       1       3  33.0  3.1       3        1  0  non-white
# 20798             4       5       3  32.0  3.0       3        2  1      white
# ...

# %%
import holisticai.datasets as hdatasets

# Check all available datasets in holisticai
print(hdatasets)  # This will give you a list of functions and available datasets
# Out:
# <module 'holisticai.datasets' from '/usr/local/lib/python3.10/dist-packages/holisticai/datasets/__init__.py'>

# %% [markdown]
# Aqui eu apelei para os datasets antigos

# %%
from holisticai.datasets import load_hai_datasets

# data, target = load_hai_datasets(dataset_name="adult")
data = load_hai_datasets(dataset_name="law_school")
# target = load_hai_datasets(dataset_name="law_school
data
# Out:
#        age  decile1  decile3  fam_inc  lsat  ugpa  gender      race1 cluster  \
# 0       62       10       10        5  44.0   3.5  female      white       1
# 1       62        5        4        4  29.0   3.5  female      white       2
# 2       61        8        7        3  37.0   3.4    male      white       1
# 3       60        8        7        4  43.0   3.3  female      white       1
# 4       57        3        2        4  41.0   3.3  female      white       4
# ...    ...      ...      ...      ...   ...   ...     ...        ...     ...
# 20795   60        9        8        4  42.0   3.0    male      white       5
# 20796   61        4        9        4  29.5   3.5    male      white       3
# 20797   62        1        1        3  33.0   3.1    male  non-white       3
# 20798   65        4        5        3  32.0   3.0    male      white       3
# 20799   60        9        3        3  36.0   3.2    male  non-white       4
#
#       fulltime    bar  ugpagt3
# ...
